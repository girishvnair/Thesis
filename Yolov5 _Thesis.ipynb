# %% [markdown]
# # Yolov5 - Object Detection

# %% [markdown]
# # Install the requirements

# %%
#!git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# /home/paperspace/jupyter_dir/yolov5
# Note: you may need to restart the kernel to use updated packages.

# %%
## %cd yolov5
# %cd yolov5
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.1-195-gb52fd48 Python-3.8.10 torch-1.11.0+cu102 CUDA:0 (Quadro M4000, 8127MiB)
# Setup complete ✅ (8 CPUs, 29.4 GB RAM, 15.6/98.3 GB disk)

# %%
# %env WANDB_NOTEBOOK_NAME="YoloV5"
# Out:
# env: WANDB_NOTEBOOK_NAME="YoloV5"

# %% [markdown]
# # Integration with Wandb

# %%
# Logging
# %pip install -q wandb
import wandb
wandb.login()
# Out:
# Note: you may need to restart the kernel to use updated packages.
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find "YoloV5".
# wandb: Currently logged in as: girishvnair. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # Loading the Model

# %%
# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # or yolov5n - yolov5x6, custom
# Out:
# Using cache found in /home/paperspace/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 v6.1-195-gb52fd48 Python-3.8.10 torch-1.11.0+cu102 CUDA:0 (Quadro M4000, 8127MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# # Fetch the custom dataset for Road Sign

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="pUHocRvgTHp6KfQtUdJx")
project = rf.workspace("school-gafxs").project("yolov5-a4r3n")
dataset = project.version(1).download("yolov5")
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.5/145.5 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.1 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 MB 20.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 16.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for roboflow: filename=roboflow-0.2.14-py3-none-any.whl size=24837 sha256=48ad28b31f88013553075027a2c289cc342ebc5543f7626cc8cb54c2ad5cf626
# ...

# %% [markdown]
# ## Fetch dataset for Road Defects

# %%
rf = Roboflow(api_key="pUHocRvgTHp6KfQtUdJx")
project = rf.workspace("school-gafxs").project("road-hazard")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to road-hazard-1 in yolov5pytorch:: 100%|██████████| 17764/17764 [00:05<00:00, 3172.80it/s]

# %% [markdown]
# # Run Training for Road Signs

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /home/paperspace/jupyter_dir/yolov5/Yolov5-1/data.yaml --weights yolov5s.pt --cache
# Out:
# wandb: Currently logged in as: girishvnair. Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=/home/paperspace/jupyter_dir/yolov5/Yolov5-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 17 (delta 11), reused 14 (delta 8), pack-reused 0
# Unpacking objects: 100% (17/17), 13.00 KiB | 950.00 KiB/s, done.
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /home/paperspace/jupyter_dir/yolov5/road-hazard-1/data.yaml --weights yolov5s.pt --cache
# Out:
# wandb: Currently logged in as: girishvnair. Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=/home/paperspace/jupyter_dir/yolov5/road-hazard-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 254 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-195-gb52fd48 Python-3.8.10 torch-1.11.0+cu102 CUDA:0 (Quadro M4000, 8127MiB)
#
# ...

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 7 --data coco128.yaml --weights yolov5s.pt --cache
# Out:
# wandb: Currently logged in as: girishvnair. Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=7, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 80 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-195-gb52fd48 Python-3.8.10 torch-1.11.0+cu102 CUDA:0 (Quadro M4000, 8127MiB)
#
# ...

# %%
# Download COCO val
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# Out:
#   0%|          | 0.00/780M [00:00<?, ?B/s]

# %%
# !python train.py --img 640 --batch 16 --epochs 300 --data coco128.yaml --weights yolov5s.pt --cache
# Out:
# wandb: Currently logged in as: girishvnair. Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 13 (delta 5), reused 6 (delta 3), pack-reused 0
# Unpacking objects: 100% (13/13), 21.29 KiB | 2.37 MiB/s, done.
# From https://github.com/ultralytics/yolov5
# ...

# %%
# %reload_ext tensorboard
# %tensorboard --host 0.0.0.0 --logdir ./runs/val/exp
# Out:
#       <iframe id="tensorboard-frame-f3931d46776d8dd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f3931d46776d8dd");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from utils.plots import plot_results 
plot_results('/home/paperspace/jupyter_dir/yolov5/runs/train/exp2/results.csv')  # plot 'results.csv' as 'results.png'
